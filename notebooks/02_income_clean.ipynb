# %%
import pandas as pd

# %%
income = pd.read_csv("../data/raw/income.csv")
income.head()
# Out:
#                    Australian Bureau of Statistics Unnamed: 1  \
# 0                                            #REF!        NaN
# 1  Released at 11:30 am (Canberra time) 22/01/2021        NaN
# 2                                            #REF!      #REF!
# 3                                              NaN        NaN
# 4                                              NaN        NaN
#
#           Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 0                NaN        NaN        NaN        NaN        NaN
# 1                NaN        NaN        NaN        NaN        NaN
# 2                NaN        NaN        NaN        NaN        NaN
# 3                NaN        NaN        NaN        NaN        NaN
# 4  Earners (persons)        NaN        NaN        NaN        NaN
#
#                       Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 26  \
# 0                            NaN        NaN        NaN  ...         NaN
# ...

# %%
# extract victoria's data
income_new = income.iloc[584:1047]

# %%
income_new.head()
# Out:
#                 Australian Bureau of Statistics        Unnamed: 1  \
# 584                                    Victoria               NaN
# 585                                   201011001         Alfredton
# 586                                   201011002          Ballarat
# 587                                   201011003  Ballarat - North
# 588                                   201011004  Ballarat - South
#
#       Unnamed: 2   Unnamed: 3   Unnamed: 4   Unnamed: 5 Unnamed: 6 Unnamed: 7  \
# 584   3,260,682    3,352,403    3,474,938    3,603,810   3,714,224        42
# 585       6,225        6,718        7,124        7,558       7,989        42
# 586       7,289        7,400        7,470        7,585       7,595        45
# 587      12,503       12,516       12,889       13,356      13,598        43
# 588      11,347       11,529       11,905       12,294      12,722        40
#
#     Unnamed: 8 Unnamed: 9  ... Unnamed: 26 Unnamed: 27 Unnamed: 28  \
# ...

# %%
# clean noisy data
income_new.dropna(how='all', axis=1, inplace=True)
income_new.head()
# Out:
# /var/folders/hc/bk1ztr7n3735c7xpl5j8qqvr0000gn/T/ipykernel_26276/3582090727.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   income_new.dropna(how='all', axis=1, inplace=True)
#                 Australian Bureau of Statistics        Unnamed: 1  \
# 584                                    Victoria               NaN
# 585                                   201011001         Alfredton
# 586                                   201011002          Ballarat
# 587                                   201011003  Ballarat - North
# 588                                   201011004  Ballarat - South
#
#       Unnamed: 2   Unnamed: 3   Unnamed: 4   Unnamed: 5 Unnamed: 6 Unnamed: 7  \
# 584   3,260,682    3,352,403    3,474,938    3,603,810   3,714,224        42
# ...

# %%
new = income_new.iloc[:, 0:7]

# %%
# arrange data by SA2 name for future matching with domain data
new.set_axis(["SA2", "SA2 NAME", "2014-15", "2015-16", "2016-17", "2017-18", "2018-19"],axis = 1, inplace = True)
new.head()
# Out:
#            SA2          SA2 NAME      2014-15      2015-16      2016-17  \
# 584   Victoria               NaN   3,260,682    3,352,403    3,474,938
# 585  201011001         Alfredton       6,225        6,718        7,124
# 586  201011002          Ballarat       7,289        7,400        7,470
# 587  201011003  Ballarat - North      12,503       12,516       12,889
# 588  201011004  Ballarat - South      11,347       11,529       11,905
#
#          2017-18    2018-19
# 584   3,603,810   3,714,224
# 585       7,558       7,989
# 586       7,585       7,595
# 587      13,356      13,598
# 588      12,294      12,722

# %%
list_income = ["SA2 NAME", "2014-15", "2015-16", "2016-17", "2017-18", "2018-19"]
# recreate dataframe with only useful columns
df = new.loc[:, list_income]
df = df.rename(columns={'SA2 NAME':'suburb', '2014-15':'2014income', \
                                '2015-16':'2015income', '2016-17':'2016income', \
                                '2017-18':'2017income', '2018-19':'2018income'})

# %%
df.reset_index(drop=True, inplace=True)

# %%
df.to_csv("../data/curated/income_person.csv")
