# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
df_a = pd.read_csv("../data/curated/match_apartment16.csv")
df_h = pd.read_csv("../data/curated/match_house16.csv")
df_a = df_a.dropna(how ="any")
df_h = df_h.dropna(how ="any")

# %%
df_a
# Out:
#      Unnamed: 0  price               suburb  beds  baths  parking  latitudes  \
# 0             0    495       EAST MELBOURNE     1      1        1 -37.816700
# 1             1    420       EAST MELBOURNE     2      1        1 -37.816700
# 2             2    550       EAST MELBOURNE     1      1        1 -37.816700
# 3             3    475       EAST MELBOURNE     1      1        0 -37.816700
# 4             4    750       EAST MELBOURNE     2      2        2 -37.816700
# ..          ...    ...                  ...   ...    ...      ...        ...
# 831         831    270  WARRNAMBOOL - SOUTH     1      1        1 -38.382624
# 832         832    350  WARRNAMBOOL - SOUTH     2      1        1 -37.000000
# 833         833    350           BEECHWORTH     2      1        1 -36.341600
# 834         834    399      HEIDELBERG WEST     2      1        1 -37.753100
# 835         835    320         MELTON SOUTH     1      1        0 -36.735900
#
#      longitudes   school  train_station  fitness_gym  hospital  \
# 0    144.987900   8137.6          381.0        345.9     620.2
# 1    144.987900   8137.6          381.0        345.9     620.2
# 2    144.987900   8137.6          381.0        345.9     620.2
# 3    144.987900   8137.6          381.0        345.9     620.2
# 4    144.987900   8137.6          381.0        345.9     620.2
# ..          ...      ...            ...          ...       ...
# 831  142.481419   3781.5       226250.3       1512.7    1185.7
# 832  145.000000  84865.1        78589.5      71347.0       0.0
# 833  146.706700  43541.8       266032.3       4585.8    3058.0
# 834  145.038500   6474.7         2807.3       1787.8    1752.6
# 835  147.152100  30231.4       338989.3      85570.6   62269.6
#
#      shopping_center     park  erp_2016  natural_increase_2016_17  \
# 0             1558.5   1235.1      5475                       6.0
# 1             1558.5   1235.1      5475                       6.0
# 2             1558.5   1235.1      5475                       6.0
# 3             1558.5   1235.1      5475                       6.0
# 4             1558.5   1235.1      5475                       6.0
# ..               ...      ...       ...                       ...
# 831           4087.1   1626.5     13173                     -13.0
# 832          78927.4  13207.1     13173                     -13.0
# 833          39795.1   2324.3      4632                     -17.0
# 834           2309.1    352.0     14806                     140.0
# 835          80656.7   2317.4     24243                     309.0
#
#      net_internal_migration_2016_17  net_overseas_migration_2016_17 2016income
# 0                              42.0                           138.0     3,792
# 1                              42.0                           138.0     3,792
# 2                              42.0                           138.0     3,792
# 3                              42.0                           138.0     3,792
# 4                              42.0                           138.0     3,792
# ..                              ...                             ...        ...
# 831                          -103.0                           146.0     7,614
# 832                          -103.0                           146.0     7,614
# 833                           102.0                             9.0     2,645
# 834                           -40.0                           212.0     7,362
# 835                          1673.0                           248.0    11,389
#
# [836 rows x 19 columns]

# %%
df_h
# Out:
#      Unnamed: 0  price            suburb  beds  baths  parking  latitudes  \
# 0             0   1100    WEST MELBOURNE     4      2        1   -37.8101
# 1             1    525    WEST MELBOURNE     2      1        1   -37.8101
# 2             2   1200    WEST MELBOURNE     3      2        1   -37.8101
# 3             3    630    WEST MELBOURNE     3      2        1   -37.8101
# 4             4    900    WEST MELBOURNE     3      2        1   -37.8101
# ..          ...    ...               ...   ...    ...      ...        ...
# 482         482    550      COBURG NORTH     3      1        2   -37.7500
# 483         483    350    SUNSHINE NORTH     3      1        1   -37.7750
# 484         484    390            WALLAN     4      2        2   -37.4180
# 485         485    450  BURNSIDE HEIGHTS     3      2        2   -37.7541
# 486         486    400          HILLSIDE     3      1        3   -37.7034
#
#      longitudes   school  train_station  fitness_gym  hospital  \
# 0      144.9500   5246.2          843.7        516.0     960.7
# 1      144.9500   5246.2          843.7        516.0     960.7
# 2      144.9500   5246.2          843.7        516.0     960.7
# 3      144.9500   5246.2          843.7        516.0     960.7
# 4      144.9500   5246.2          843.7        516.0     960.7
# ..          ...      ...            ...          ...       ...
# 482    144.9667   3099.5          888.5       1617.6    1255.4
# 483    144.8333   5655.2         1159.4       1384.3    3950.7
# 484    145.0166  56845.3        25412.9      16742.7   19610.5
# 485    144.7651   3773.4         4544.8       5859.0    2764.3
# 486    144.7619   1338.7         2537.4       1967.6    5678.8
#
#      shopping_center    park  erp_2016  natural_increase_2016_17  \
# 0              737.0  3319.6         3                       0.0
# 1              737.0  3319.6         3                       0.0
# 2              737.0  3319.6         3                       0.0
# 3              737.0  3319.6         3                       0.0
# 4              737.0  3319.6         3                       0.0
# ..               ...     ...       ...                       ...
# 482           3204.2  1478.4      8112                      59.0
# 483           1418.2   474.8     12123                      75.0
# 484          25750.8  3562.8     16747                     215.0
# 485           1320.5  1817.3      6431                      93.0
# 486           2815.4  2055.4     21305                     318.0
#
#      net_internal_migration_2016_17  net_overseas_migration_2016_17 2016income
# 0                               0.0                             0.0         6
# 1                               0.0                             0.0         6
# 2                               0.0                             0.0         6
# 3                               0.0                             0.0         6
# 4                               0.0                             0.0         6
# ..                              ...                             ...        ...
# 482                            99.0                           140.0     4,649
# 483                           -67.0                           200.0     5,690
# 484                           442.0                            62.0     9,623
# 485                           -52.0                            87.0     3,251
# 486                          1101.0                           189.0    11,999
#
# [487 rows x 19 columns]

# %%
df_a.drop_duplicates(keep='first',inplace=True)
df_h.drop_duplicates(keep='first',inplace=True)

# %%
df_a.duplicated().value_counts()
# Out:
# False    836
# dtype: int64

# %%
df_h.duplicated().value_counts()
# Out:
# False    487
# dtype: int64

# %%
df_a.isnull()
# Out:
#      Unnamed: 0  price  suburb   beds  baths  parking  latitudes  longitudes  \
# 0         False  False   False  False  False    False      False       False
# 1         False  False   False  False  False    False      False       False
# 2         False  False   False  False  False    False      False       False
# 3         False  False   False  False  False    False      False       False
# 4         False  False   False  False  False    False      False       False
# ..          ...    ...     ...    ...    ...      ...        ...         ...
# 831       False  False   False  False  False    False      False       False
# 832       False  False   False  False  False    False      False       False
# 833       False  False   False  False  False    False      False       False
# 834       False  False   False  False  False    False      False       False
# 835       False  False   False  False  False    False      False       False
#
#      school  train_station  fitness_gym  hospital  shopping_center   park  \
# 0     False          False        False     False            False  False
# 1     False          False        False     False            False  False
# 2     False          False        False     False            False  False
# 3     False          False        False     False            False  False
# 4     False          False        False     False            False  False
# ..      ...            ...          ...       ...              ...    ...
# 831   False          False        False     False            False  False
# 832   False          False        False     False            False  False
# 833   False          False        False     False            False  False
# 834   False          False        False     False            False  False
# 835   False          False        False     False            False  False
#
#      erp_2016  natural_increase_2016_17  net_internal_migration_2016_17  \
# 0       False                     False                           False
# 1       False                     False                           False
# 2       False                     False                           False
# 3       False                     False                           False
# 4       False                     False                           False
# ..        ...                       ...                             ...
# 831     False                     False                           False
# 832     False                     False                           False
# 833     False                     False                           False
# 834     False                     False                           False
# 835     False                     False                           False
#
#      net_overseas_migration_2016_17  2016income
# 0                             False       False
# 1                             False       False
# 2                             False       False
# 3                             False       False
# 4                             False       False
# ..                              ...         ...
# 831                           False       False
# 832                           False       False
# 833                           False       False
# 834                           False       False
# 835                           False       False
#
# [836 rows x 19 columns]

# %%
df_h.isnull()
# Out:
#      Unnamed: 0  price  suburb   beds  baths  parking  latitudes  longitudes  \
# 0         False  False   False  False  False    False      False       False
# 1         False  False   False  False  False    False      False       False
# 2         False  False   False  False  False    False      False       False
# 3         False  False   False  False  False    False      False       False
# 4         False  False   False  False  False    False      False       False
# ..          ...    ...     ...    ...    ...      ...        ...         ...
# 482       False  False   False  False  False    False      False       False
# 483       False  False   False  False  False    False      False       False
# 484       False  False   False  False  False    False      False       False
# 485       False  False   False  False  False    False      False       False
# 486       False  False   False  False  False    False      False       False
#
#      school  train_station  fitness_gym  hospital  shopping_center   park  \
# 0     False          False        False     False            False  False
# 1     False          False        False     False            False  False
# 2     False          False        False     False            False  False
# 3     False          False        False     False            False  False
# 4     False          False        False     False            False  False
# ..      ...            ...          ...       ...              ...    ...
# 482   False          False        False     False            False  False
# 483   False          False        False     False            False  False
# 484   False          False        False     False            False  False
# 485   False          False        False     False            False  False
# 486   False          False        False     False            False  False
#
#      erp_2016  natural_increase_2016_17  net_internal_migration_2016_17  \
# 0       False                     False                           False
# 1       False                     False                           False
# 2       False                     False                           False
# 3       False                     False                           False
# 4       False                     False                           False
# ..        ...                       ...                             ...
# 482     False                     False                           False
# 483     False                     False                           False
# 484     False                     False                           False
# 485     False                     False                           False
# 486     False                     False                           False
#
#      net_overseas_migration_2016_17  2016income
# 0                             False       False
# 1                             False       False
# 2                             False       False
# 3                             False       False
# 4                             False       False
# ..                              ...         ...
# 482                           False       False
# 483                           False       False
# 484                           False       False
# 485                           False       False
# 486                           False       False
#
# [487 rows x 19 columns]

# %%
df_a.to_csv('../data/curated/match_clean_apartment.csv',encoding='utf-8')
df_h.to_csv('../data/curated/match_clean_house.csv',encoding='utf-8')

# %%
import seaborn as sns
import matplotlib.pyplot as plt


#boxplot-apartment-facilities

df1_a = pd.read_csv('../data/curated/match_clean_apartment.csv')
labels = 'school','train_station', 'fitness_gym', 'hospital', 'shopping_center', 'park','natural_increase_2016_17'

school = df1_a.school
train_station = df1_a.train_station
fitness_gym = df1_a.fitness_gym
hospital = df1_a.hospital
shopping_center = df1_a.shopping_center
park = df1_a.park
increase_16 = df1_a.natural_increase_2016_17

plt.grid(True) 
plt.boxplot([school, train_station, fitness_gym, hospital, shopping_center, park, increase_16],
            medianprops={'color': 'red', 'linewidth': '1.5'},
            meanline=True,
            showmeans=True,
            meanprops={'color': 'blue', 'ls': '--', 'linewidth': '1.5'},
            flierprops={"marker": "o", "markerfacecolor": "pink", "markersize": 5},
            labels=labels)
plt.yticks(np.arange(0, 1000, 50000))
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt


#boxplot-house-facilities

df1_h = pd.read_csv('../data/curated/match_clean_house.csv')
labels = 'school','train_station', 'fitness_gym', 'hospital', 'shopping_center', 'park','natural_increase_2016_17'
school = df1_h.school
train_station = df1_h.train_station
fitness_gym = df1_h.fitness_gym
hospital = df1_h.hospital
shopping_center = df1_h.shopping_center
park = df1_h.park
increase_16 = df1_h.natural_increase_2016_17

plt.grid(True) 
plt.boxplot([school, train_station, fitness_gym, hospital, shopping_center, park, increase_16],
            medianprops={'color': 'red', 'linewidth': '1.5'},
            meanline=True,
            showmeans=True,
            meanprops={'color': 'blue', 'ls': '--', 'linewidth': '1.5'},
            flierprops={"marker": "o", "markerfacecolor": "pink", "markersize": 5},
            labels=labels)
plt.yticks(np.arange(0, 5000, 50000))
plt.show()

# %%
##Q1 = match_clean.train_station.quantile(q = 0.25)
##Q3 = match_clean.train_station.quantile(q = 0.75)


##low_bound = Q1 - 1.5*(Q3 - Q1)
##up_bound = Q3 + 1.5*(Q3 - Q1)

##match_clean.train_station[(match_clean.train_station > up_bound) | (match_clean.train_station < low_bound)]

# %%
for i in ['school','train_station','fitness_gym','hospital','shopping_center','park','natural_increase_2016_17']:
    sns.histplot(df1_a[i],bins=50)
    plt.show()

# %%
###selecting data for apartment

# %%
#delete outlier/ extreme points

df = pd.read_csv("../data/curated/match_clean_apartment.csv")
df = df[df['school']<=40000]
df = df[df['train_station']<=20000]
df = df[df['fitness_gym']<=20000]
df = df[df['hospital']<=20000]
df = df[df['shopping_center']<=50000]
df = df[df['park']<=15000]
df = df[df['natural_increase_2016_17']>=10] #should be positive
df.shape
# Out:
# (679, 20)

# %%
#save to csv
df.to_csv('../data/curated/clean_fit_apartment.csv')
df
# Out:
#      Unnamed: 0  Unnamed: 0.1  price           suburb  beds  baths  parking  \
# 19           19            19    595          HIGHTON     2      2        1
# 20           20            20    430          HIGHTON     2      1        1
# 21           21            21    525          HIGHTON     2      1        1
# 22           22            22    460          HIGHTON     2      1        1
# 23           23            23    390          HIGHTON     2      1        2
# ..          ...           ...    ...              ...   ...    ...      ...
# 826         826           826    390    CROYDON SOUTH     2      1        1
# 827         827           827    400          VERMONT     2      1        2
# 829         829           829    320   ALTONA MEADOWS     2      1        1
# 830         830           830    460       WINCHELSEA     3      1        2
# 834         834           834    399  HEIDELBERG WEST     2      1        1
#
#      latitudes  longitudes  school  train_station  fitness_gym  hospital  \
# 19    -37.9057    145.0067  2985.3          635.1        670.0    1203.5
# 20    -37.9517    145.0394  5491.7          671.7       1100.0    2370.4
# 21    -37.9057    145.0067  2985.3          635.1        670.0    1203.5
# 22    -37.7829    145.0226  6800.6         1181.2        847.9     680.2
# 23    -37.9517    145.0394  5491.7          671.7       1100.0    2370.4
# ..         ...         ...     ...            ...          ...       ...
# 826   -37.7744    145.2756  9621.1         2971.4       3339.8    3037.1
# 827   -37.8362    145.1943  5514.0         2555.3       2337.4    2896.5
# 829   -37.8809    144.7587  9417.7         2434.3       2961.5    7570.4
# 830   -38.0372    145.1097  5517.5          316.3       3499.2    9575.8
# 834   -37.7531    145.0385  6474.7         2807.3       1787.8    1752.6
#
#      shopping_center    park  erp_2016  natural_increase_2016_17  \
# 19            5551.3   884.0     22794                      99.0
# 20             505.5  1197.1     22794                      99.0
# 21            5551.3   884.0     22794                      99.0
# 22            2692.3   986.3     22794                      99.0
# 23             505.5  1197.1     22794                      99.0
# ..               ...     ...       ...                       ...
# 826           2817.4  1873.1      4856                      49.0
# 827           2456.5   651.1     10896                      56.0
# 829           3084.5  1336.8     20106                     116.0
# 830           4087.3  1010.0      5824                      14.0
# 834           2309.1   352.0     14806                     140.0
#
#      net_internal_migration_2016_17  net_overseas_migration_2016_17 2016income
# 19                           -101.0                           270.0    13,542
# 20                           -101.0                           270.0    13,542
# 21                           -101.0                           270.0    13,542
# 22                           -101.0                           270.0    13,542
# 23                           -101.0                           270.0    13,542
# ..                              ...                             ...        ...
# 826                           -47.0                            41.0     2,715
# 827                           -91.0                           180.0     6,306
# 829                          -145.0                           236.0    10,722
# 830                           -15.0                             7.0     3,647
# 834                           -40.0                           212.0     7,362
#
# [679 rows x 20 columns]

# %%
#check apartment data
for i in ['train_station','fitness_gym','hospital','shopping_center','park','natural_increase_2016_17']:
    sns.histplot(df[i],bins=50)
    plt.show()

# %%
###selecting data for house

# %%
for i in ['school','train_station','fitness_gym','hospital','shopping_center','park','natural_increase_2016_17']:
    sns.histplot(df1_h[i],bins=50)
    plt.show()

# %%
#delete outlier/ extreme points  for house

df = pd.read_csv("../data/curated/match_clean_house.csv")
df = df[df['school']<=50000]
df = df[df['train_station']<=100000]
df = df[df['fitness_gym']<=25000]
df = df[df['hospital']<=25000]
df = df[df['shopping_center']<=50000]
df = df[df['park']<=15000]
df = df[df['natural_increase_2016_17']>=10]

df.shape
# Out:
# (405, 20)

# %%
#save to csv

df.to_csv('../data/curated/clean_fit_house.csv')
df
# Out:
#      Unnamed: 0  Unnamed: 0.1  price            suburb  beds  baths  parking  \
# 5             5             5    720     ST KILDA EAST     3      2        1
# 6             6             6    850     ST KILDA EAST     3      1        0
# 7             7             7    780     ST KILDA EAST     3      1        0
# 8             8             8   1650     ST KILDA EAST     5      2        4
# 9             9             9    720     ST KILDA EAST     3      2        1
# ..          ...           ...    ...               ...   ...    ...      ...
# 481         481           481    500        SOMERVILLE     3      2        2
# 482         482           482    550      COBURG NORTH     3      1        2
# 483         483           483    350    SUNSHINE NORTH     3      1        1
# 485         485           485    450  BURNSIDE HEIGHTS     3      2        2
# 486         486           486    400          HILLSIDE     3      1        3
#
#      latitudes  longitudes  school  train_station  fitness_gym  hospital  \
# 5     -37.8692    144.9977  8801.2          740.6       1818.7     176.2
# 6     -37.8692    144.9977  8801.2          740.6       1818.7     176.2
# 7     -37.8692    144.9977  8801.2          740.6       1818.7     176.2
# 8     -37.8692    144.9977  8801.2          740.6       1818.7     176.2
# 9     -37.8692    144.9977  8801.2          740.6       1818.7     176.2
# ..         ...         ...     ...            ...          ...       ...
# 481   -38.2186    145.2182  9392.4         6435.0       4854.6   10188.3
# 482   -37.7500    144.9667  3099.5          888.5       1617.6    1255.4
# 483   -37.7750    144.8333  5655.2         1159.4       1384.3    3950.7
# 485   -37.7541    144.7651  3773.4         4544.8       5859.0    2764.3
# 486   -37.7034    144.7619  1338.7         2537.4       1967.6    5678.8
#
#      shopping_center    park  erp_2016  natural_increase_2016_17  \
# 5             1684.7  1184.2     17613                     195.0
# 6             1684.7  1184.2     17613                     195.0
# 7             1684.7  1184.2     17613                     195.0
# 8             1684.7  1184.2     17613                     195.0
# 9             1684.7  1184.2     17613                     195.0
# ..               ...     ...       ...                       ...
# 481          11544.9  3464.7     18878                      76.0
# 482           3204.2  1478.4      8112                      59.0
# 483           1418.2   474.8     12123                      75.0
# 485           1320.5  1817.3      6431                      93.0
# 486           2815.4  2055.4     21305                     318.0
#
#      net_internal_migration_2016_17  net_overseas_migration_2016_17 2016income
# 5                            -267.0                           375.0    11,686
# 6                            -267.0                           375.0    11,686
# 7                            -267.0                           375.0    11,686
# 8                            -267.0                           375.0    11,686
# 9                            -267.0                           375.0    11,686
# ..                              ...                             ...        ...
# 481                           113.0                            50.0    11,166
# 482                            99.0                           140.0     4,649
# 483                           -67.0                           200.0     5,690
# 485                           -52.0                            87.0     3,251
# 486                          1101.0                           189.0    11,999
#
# [405 rows x 20 columns]

# %%
#check house data
for i in ['train_station','fitness_gym','hospital','shopping_center','park','natural_increase_2016_17']:
    sns.histplot(df[i],bins=50)
    plt.show()

# %%
##

# %%
for i in ['train_station','fitness_gym','hospital','shopping_center','park']:
    df1 = df[[i,'price']].groupby(i).mean().reset_index()
    sns.regplot(x=i,y='price',data=df1)
    plt.show()

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline


df_a = pd.read_csv("../data/curated/match_apartment16.csv")
df_h = pd.read_csv("../data/curated/match_house16.csv")
df_a = df_a.dropna(how ="any")
df_h = df_h.dropna(how ="any")



df_a

df_h

df_a.drop_duplicates(keep='first',inplace=True)
df_h.drop_duplicates(keep='first',inplace=True)

df_a.duplicated().value_counts()

df_h.duplicated().value_counts()

df_a.isnull()

df_h.isnull()

df_a.to_csv('../data/curated/match_clean_apartment.csv',encoding='utf-8')
df_h.to_csv('../data/curated/match_clean_house.csv',encoding='utf-8')

import seaborn as sns
import matplotlib.pyplot as plt


#boxplot-apartment-facilities

df1_a = pd.read_csv('../data/curated/match_clean_apartment.csv')
labels = 'school','train_station', 'fitness_gym', 'hospital', 'shopping_center', 'park','natural_increase_2016_17'

school = df1_a.school
train_station = df1_a.train_station
fitness_gym = df1_a.fitness_gym
hospital = df1_a.hospital
shopping_center = df1_a.shopping_center
park = df1_a.park
increase_16 = df1_a.natural_increase_2016_17

plt.grid(True) 
plt.boxplot([school, train_station, fitness_gym, hospital, shopping_center, park, increase_16],
            medianprops={'color': 'red', 'linewidth': '1.5'},
            meanline=True,
            showmeans=True,
            meanprops={'color': 'blue', 'ls': '--', 'linewidth': '1.5'},
            flierprops={"marker": "o", "markerfacecolor": "pink", "markersize": 5},
            labels=labels)
plt.yticks(np.arange(0, 1000, 50000))
plt.show()



import seaborn as sns
import matplotlib.pyplot as plt


#boxplot-house-facilities

df1_h = pd.read_csv('../data/curated/match_clean_house.csv')
labels = 'school','train_station', 'fitness_gym', 'hospital', 'shopping_center', 'park','natural_increase_2016_17'
school = df1_h.school
train_station = df1_h.train_station
fitness_gym = df1_h.fitness_gym
hospital = df1_h.hospital
shopping_center = df1_h.shopping_center
park = df1_h.park
increase_16 = df1_h.natural_increase_2016_17

plt.grid(True) 
plt.boxplot([school, train_station, fitness_gym, hospital, shopping_center, park, increase_16],
            medianprops={'color': 'red', 'linewidth': '1.5'},
            meanline=True,
            showmeans=True,
            meanprops={'color': 'blue', 'ls': '--', 'linewidth': '1.5'},
            flierprops={"marker": "o", "markerfacecolor": "pink", "markersize": 5},
            labels=labels)
plt.yticks(np.arange(0, 5000, 50000))
plt.show()


##Q1 = match_clean.train_station.quantile(q = 0.25)
##Q3 = match_clean.train_station.quantile(q = 0.75)


##low_bound = Q1 - 1.5*(Q3 - Q1)
##up_bound = Q3 + 1.5*(Q3 - Q1)

##match_clean.train_station[(match_clean.train_station > up_bound) | (match_clean.train_station < low_bound)]

for i in ['school','train_station','fitness_gym','hospital','shopping_center','park','natural_increase_2016_17']:
    sns.histplot(df1_a[i],bins=50)
    plt.show()

###selecting data for apartment

#delete outlier/ extreme points

df = pd.read_csv("../data/curated/match_clean_apartment.csv")
df = df[df['school']<=40000]
df = df[df['train_station']<=20000]
df = df[df['fitness_gym']<=20000]
df = df[df['hospital']<=20000]
df = df[df['shopping_center']<=50000]
df = df[df['park']<=15000]
df = df[df['natural_increase_2016_17']>=10] #should be positive
df.shape

#save to csv
df.to_csv('../data/curated/clean_fit_apartment.csv')
df

#check apartment data
for i in ['train_station','fitness_gym','hospital','shopping_center','park','natural_increase_2016_17']:
    sns.histplot(df[i],bins=50)
    plt.show()

###selecting data for house

for i in ['school','train_station','fitness_gym','hospital','shopping_center','park','natural_increase_2016_17']:
    sns.histplot(df1_h[i],bins=50)
    plt.show()

#delete outlier/ extreme points  for house

df = pd.read_csv("../data/curated/match_clean_house.csv")
df = df[df['school']<=50000]
df = df[df['train_station']<=100000]
df = df[df['fitness_gym']<=25000]
df = df[df['hospital']<=25000]
df = df[df['shopping_center']<=50000]
df = df[df['park']<=15000]
df = df[df['natural_increase_2016_17']>=10]

df.shape

#save to csv

df.to_csv('../data/curated/clean_fit_house.csv')
df


#check house data
for i in ['train_station','fitness_gym','hospital','shopping_center','park','natural_increase_2016_17']:
    sns.histplot(df[i],bins=50)
    plt.show()

##

for i in ['train_station','fitness_gym','hospital','shopping_center','park']:
    df1 = df[[i,'price']].groupby(i).mean().reset_index()
    sns.regplot(x=i,y='price',data=df1)
    plt.show()

import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
df_a = pd.read_csv("../data/curated/match_apartment16.csv")
df_h = pd.read_csv("../data/curated/match_house16.csv")
df_a = df_a.dropna(how ="any")
df_h = df_h.dropna(how ="any")

# %%
df_a
# Out:
#      Unnamed: 0  price               suburb  beds  baths  parking  latitudes  \
# 0             0    495       EAST MELBOURNE     1      1        1 -37.816700
# 1             1    420       EAST MELBOURNE     2      1        1 -37.816700
# 2             2    550       EAST MELBOURNE     1      1        1 -37.816700
# 3             3    475       EAST MELBOURNE     1      1        0 -37.816700
# 4             4    750       EAST MELBOURNE     2      2        2 -37.816700
# ..          ...    ...                  ...   ...    ...      ...        ...
# 831         831    270  WARRNAMBOOL - SOUTH     1      1        1 -38.382624
# 832         832    350  WARRNAMBOOL - SOUTH     2      1        1 -37.000000
# 833         833    350           BEECHWORTH     2      1        1 -36.341600
# 834         834    399      HEIDELBERG WEST     2      1        1 -37.753100
# 835         835    320         MELTON SOUTH     1      1        0 -36.735900
#
#      longitudes   school  train_station  fitness_gym  hospital  \
# 0    144.987900   8137.6          381.0        345.9     620.2
# 1    144.987900   8137.6          381.0        345.9     620.2
# 2    144.987900   8137.6          381.0        345.9     620.2
# 3    144.987900   8137.6          381.0        345.9     620.2
# 4    144.987900   8137.6          381.0        345.9     620.2
# ..          ...      ...            ...          ...       ...
# 831  142.481419   3781.5       226250.3       1512.7    1185.7
# 832  145.000000  84865.1        78589.5      71347.0       0.0
# 833  146.706700  43541.8       266032.3       4585.8    3058.0
# 834  145.038500   6474.7         2807.3       1787.8    1752.6
# 835  147.152100  30231.4       338989.3      85570.6   62269.6
#
#      shopping_center     park  erp_2016  natural_increase_2016_17  \
# 0             1558.5   1235.1      5475                       6.0
# 1             1558.5   1235.1      5475                       6.0
# 2             1558.5   1235.1      5475                       6.0
# 3             1558.5   1235.1      5475                       6.0
# 4             1558.5   1235.1      5475                       6.0
# ..               ...      ...       ...                       ...
# 831           4087.1   1626.5     13173                     -13.0
# 832          78927.4  13207.1     13173                     -13.0
# 833          39795.1   2324.3      4632                     -17.0
# 834           2309.1    352.0     14806                     140.0
# 835          80656.7   2317.4     24243                     309.0
#
#      net_internal_migration_2016_17  net_overseas_migration_2016_17 2016income
# 0                              42.0                           138.0     3,792
# 1                              42.0                           138.0     3,792
# 2                              42.0                           138.0     3,792
# 3                              42.0                           138.0     3,792
# 4                              42.0                           138.0     3,792
# ..                              ...                             ...        ...
# 831                          -103.0                           146.0     7,614
# 832                          -103.0                           146.0     7,614
# 833                           102.0                             9.0     2,645
# 834                           -40.0                           212.0     7,362
# 835                          1673.0                           248.0    11,389
#
# [836 rows x 19 columns]

# %%
df_h
# Out:
#      Unnamed: 0  price            suburb  beds  baths  parking  latitudes  \
# 0             0   1100    WEST MELBOURNE     4      2        1   -37.8101
# 1             1    525    WEST MELBOURNE     2      1        1   -37.8101
# 2             2   1200    WEST MELBOURNE     3      2        1   -37.8101
# 3             3    630    WEST MELBOURNE     3      2        1   -37.8101
# 4             4    900    WEST MELBOURNE     3      2        1   -37.8101
# ..          ...    ...               ...   ...    ...      ...        ...
# 482         482    550      COBURG NORTH     3      1        2   -37.7500
# 483         483    350    SUNSHINE NORTH     3      1        1   -37.7750
# 484         484    390            WALLAN     4      2        2   -37.4180
# 485         485    450  BURNSIDE HEIGHTS     3      2        2   -37.7541
# 486         486    400          HILLSIDE     3      1        3   -37.7034
#
#      longitudes   school  train_station  fitness_gym  hospital  \
# 0      144.9500   5246.2          843.7        516.0     960.7
# 1      144.9500   5246.2          843.7        516.0     960.7
# 2      144.9500   5246.2          843.7        516.0     960.7
# 3      144.9500   5246.2          843.7        516.0     960.7
# 4      144.9500   5246.2          843.7        516.0     960.7
# ..          ...      ...            ...          ...       ...
# 482    144.9667   3099.5          888.5       1617.6    1255.4
# 483    144.8333   5655.2         1159.4       1384.3    3950.7
# 484    145.0166  56845.3        25412.9      16742.7   19610.5
# 485    144.7651   3773.4         4544.8       5859.0    2764.3
# 486    144.7619   1338.7         2537.4       1967.6    5678.8
#
#      shopping_center    park  erp_2016  natural_increase_2016_17  \
# 0              737.0  3319.6         3                       0.0
# 1              737.0  3319.6         3                       0.0
# 2              737.0  3319.6         3                       0.0
# 3              737.0  3319.6         3                       0.0
# 4              737.0  3319.6         3                       0.0
# ..               ...     ...       ...                       ...
# 482           3204.2  1478.4      8112                      59.0
# 483           1418.2   474.8     12123                      75.0
# 484          25750.8  3562.8     16747                     215.0
# 485           1320.5  1817.3      6431                      93.0
# 486           2815.4  2055.4     21305                     318.0
#
#      net_internal_migration_2016_17  net_overseas_migration_2016_17 2016income
# 0                               0.0                             0.0         6
# 1                               0.0                             0.0         6
# 2                               0.0                             0.0         6
# 3                               0.0                             0.0         6
# 4                               0.0                             0.0         6
# ..                              ...                             ...        ...
# 482                            99.0                           140.0     4,649
# 483                           -67.0                           200.0     5,690
# 484                           442.0                            62.0     9,623
# 485                           -52.0                            87.0     3,251
# 486                          1101.0                           189.0    11,999
#
# [487 rows x 19 columns]

# %%
df_a.drop_duplicates(keep='first',inplace=True)
df_h.drop_duplicates(keep='first',inplace=True)

# %%
df_a.duplicated().value_counts()
# Out:
# False    836
# dtype: int64

# %%
df_h.duplicated().value_counts()
# Out:
# False    487
# dtype: int64

# %%
df_a.isnull()
# Out:
#      Unnamed: 0  price  suburb   beds  baths  parking  latitudes  longitudes  \
# 0         False  False   False  False  False    False      False       False
# 1         False  False   False  False  False    False      False       False
# 2         False  False   False  False  False    False      False       False
# 3         False  False   False  False  False    False      False       False
# 4         False  False   False  False  False    False      False       False
# ..          ...    ...     ...    ...    ...      ...        ...         ...
# 831       False  False   False  False  False    False      False       False
# 832       False  False   False  False  False    False      False       False
# 833       False  False   False  False  False    False      False       False
# 834       False  False   False  False  False    False      False       False
# 835       False  False   False  False  False    False      False       False
#
#      school  train_station  fitness_gym  hospital  shopping_center   park  \
# 0     False          False        False     False            False  False
# 1     False          False        False     False            False  False
# 2     False          False        False     False            False  False
# 3     False          False        False     False            False  False
# 4     False          False        False     False            False  False
# ..      ...            ...          ...       ...              ...    ...
# 831   False          False        False     False            False  False
# 832   False          False        False     False            False  False
# 833   False          False        False     False            False  False
# 834   False          False        False     False            False  False
# 835   False          False        False     False            False  False
#
#      erp_2016  natural_increase_2016_17  net_internal_migration_2016_17  \
# 0       False                     False                           False
# 1       False                     False                           False
# 2       False                     False                           False
# 3       False                     False                           False
# 4       False                     False                           False
# ..        ...                       ...                             ...
# 831     False                     False                           False
# 832     False                     False                           False
# 833     False                     False                           False
# 834     False                     False                           False
# 835     False                     False                           False
#
#      net_overseas_migration_2016_17  2016income
# 0                             False       False
# 1                             False       False
# 2                             False       False
# 3                             False       False
# 4                             False       False
# ..                              ...         ...
# 831                           False       False
# 832                           False       False
# 833                           False       False
# 834                           False       False
# 835                           False       False
#
# [836 rows x 19 columns]

# %%
df_h.isnull()
# Out:
#      Unnamed: 0  price  suburb   beds  baths  parking  latitudes  longitudes  \
# 0         False  False   False  False  False    False      False       False
# 1         False  False   False  False  False    False      False       False
# 2         False  False   False  False  False    False      False       False
# 3         False  False   False  False  False    False      False       False
# 4         False  False   False  False  False    False      False       False
# ..          ...    ...     ...    ...    ...      ...        ...         ...
# 482       False  False   False  False  False    False      False       False
# 483       False  False   False  False  False    False      False       False
# 484       False  False   False  False  False    False      False       False
# 485       False  False   False  False  False    False      False       False
# 486       False  False   False  False  False    False      False       False
#
#      school  train_station  fitness_gym  hospital  shopping_center   park  \
# 0     False          False        False     False            False  False
# 1     False          False        False     False            False  False
# 2     False          False        False     False            False  False
# 3     False          False        False     False            False  False
# 4     False          False        False     False            False  False
# ..      ...            ...          ...       ...              ...    ...
# 482   False          False        False     False            False  False
# 483   False          False        False     False            False  False
# 484   False          False        False     False            False  False
# 485   False          False        False     False            False  False
# 486   False          False        False     False            False  False
#
#      erp_2016  natural_increase_2016_17  net_internal_migration_2016_17  \
# 0       False                     False                           False
# 1       False                     False                           False
# 2       False                     False                           False
# 3       False                     False                           False
# 4       False                     False                           False
# ..        ...                       ...                             ...
# 482     False                     False                           False
# 483     False                     False                           False
# 484     False                     False                           False
# 485     False                     False                           False
# 486     False                     False                           False
#
#      net_overseas_migration_2016_17  2016income
# 0                             False       False
# 1                             False       False
# 2                             False       False
# 3                             False       False
# 4                             False       False
# ..                              ...         ...
# 482                           False       False
# 483                           False       False
# 484                           False       False
# 485                           False       False
# 486                           False       False
#
# [487 rows x 19 columns]

# %%
df_a.to_csv('../data/curated/match_clean_apartment.csv',encoding='utf-8')
df_h.to_csv('../data/curated/match_clean_house.csv',encoding='utf-8')

# %%
import seaborn as sns
import matplotlib.pyplot as plt


#boxplot-apartment-facilities

df1_a = pd.read_csv('../data/curated/match_clean_apartment.csv')
labels = 'school','train_station', 'fitness_gym', 'hospital', 'shopping_center', 'park','natural_increase_2016_17'

school = df1_a.school
train_station = df1_a.train_station
fitness_gym = df1_a.fitness_gym
hospital = df1_a.hospital
shopping_center = df1_a.shopping_center
park = df1_a.park
increase_16 = df1_a.natural_increase_2016_17

plt.grid(True) 
plt.boxplot([school, train_station, fitness_gym, hospital, shopping_center, park, increase_16],
            medianprops={'color': 'red', 'linewidth': '1.5'},
            meanline=True,
            showmeans=True,
            meanprops={'color': 'blue', 'ls': '--', 'linewidth': '1.5'},
            flierprops={"marker": "o", "markerfacecolor": "pink", "markersize": 5},
            labels=labels)
plt.yticks(np.arange(0, 1000, 50000))
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt


#boxplot-house-facilities

df1_h = pd.read_csv('../data/curated/match_clean_house.csv')
labels = 'school','train_station', 'fitness_gym', 'hospital', 'shopping_center', 'park','natural_increase_2016_17'
school = df1_h.school
train_station = df1_h.train_station
fitness_gym = df1_h.fitness_gym
hospital = df1_h.hospital
shopping_center = df1_h.shopping_center
park = df1_h.park
increase_16 = df1_h.natural_increase_2016_17

plt.grid(True) 
plt.boxplot([school, train_station, fitness_gym, hospital, shopping_center, park, increase_16],
            medianprops={'color': 'red', 'linewidth': '1.5'},
            meanline=True,
            showmeans=True,
            meanprops={'color': 'blue', 'ls': '--', 'linewidth': '1.5'},
            flierprops={"marker": "o", "markerfacecolor": "pink", "markersize": 5},
            labels=labels)
plt.yticks(np.arange(0, 5000, 50000))
plt.show()

# %%
##Q1 = match_clean.train_station.quantile(q = 0.25)
##Q3 = match_clean.train_station.quantile(q = 0.75)


##low_bound = Q1 - 1.5*(Q3 - Q1)
##up_bound = Q3 + 1.5*(Q3 - Q1)

##match_clean.train_station[(match_clean.train_station > up_bound) | (match_clean.train_station < low_bound)]

# %%
for i in ['school','train_station','fitness_gym','hospital','shopping_center','park','natural_increase_2016_17']:
    sns.histplot(df1_a[i],bins=50)
    plt.show()

# %%
###selecting data for apartment

# %%
#delete outlier/ extreme points

df = pd.read_csv("../data/curated/match_clean_apartment.csv")
df = df[df['school']<=40000]
df = df[df['train_station']<=20000]
df = df[df['fitness_gym']<=20000]
df = df[df['hospital']<=20000]
df = df[df['shopping_center']<=50000]
df = df[df['park']<=15000]
df = df[df['natural_increase_2016_17']>=10] 
df.shape
# Out:
# (679, 20)

# %%
#save to csv
df.to_csv('../data/curated/match_apartment16_s.csv')
df
# Out:
#      Unnamed: 0  Unnamed: 0.1  price           suburb  beds  baths  parking  \
# 19           19            19    595          HIGHTON     2      2        1
# 20           20            20    430          HIGHTON     2      1        1
# 21           21            21    525          HIGHTON     2      1        1
# 22           22            22    460          HIGHTON     2      1        1
# 23           23            23    390          HIGHTON     2      1        2
# ..          ...           ...    ...              ...   ...    ...      ...
# 826         826           826    390    CROYDON SOUTH     2      1        1
# 827         827           827    400          VERMONT     2      1        2
# 829         829           829    320   ALTONA MEADOWS     2      1        1
# 830         830           830    460       WINCHELSEA     3      1        2
# 834         834           834    399  HEIDELBERG WEST     2      1        1
#
#      latitudes  longitudes  school  train_station  fitness_gym  hospital  \
# 19    -37.9057    145.0067  2985.3          635.1        670.0    1203.5
# 20    -37.9517    145.0394  5491.7          671.7       1100.0    2370.4
# 21    -37.9057    145.0067  2985.3          635.1        670.0    1203.5
# 22    -37.7829    145.0226  6800.6         1181.2        847.9     680.2
# 23    -37.9517    145.0394  5491.7          671.7       1100.0    2370.4
# ..         ...         ...     ...            ...          ...       ...
# 826   -37.7744    145.2756  9621.1         2971.4       3339.8    3037.1
# 827   -37.8362    145.1943  5514.0         2555.3       2337.4    2896.5
# 829   -37.8809    144.7587  9417.7         2434.3       2961.5    7570.4
# 830   -38.0372    145.1097  5517.5          316.3       3499.2    9575.8
# 834   -37.7531    145.0385  6474.7         2807.3       1787.8    1752.6
#
#      shopping_center    park  erp_2016  natural_increase_2016_17  \
# 19            5551.3   884.0     22794                      99.0
# 20             505.5  1197.1     22794                      99.0
# 21            5551.3   884.0     22794                      99.0
# 22            2692.3   986.3     22794                      99.0
# 23             505.5  1197.1     22794                      99.0
# ..               ...     ...       ...                       ...
# 826           2817.4  1873.1      4856                      49.0
# 827           2456.5   651.1     10896                      56.0
# 829           3084.5  1336.8     20106                     116.0
# 830           4087.3  1010.0      5824                      14.0
# 834           2309.1   352.0     14806                     140.0
#
#      net_internal_migration_2016_17  net_overseas_migration_2016_17 2016income
# 19                           -101.0                           270.0    13,542
# 20                           -101.0                           270.0    13,542
# 21                           -101.0                           270.0    13,542
# 22                           -101.0                           270.0    13,542
# 23                           -101.0                           270.0    13,542
# ..                              ...                             ...        ...
# 826                           -47.0                            41.0     2,715
# 827                           -91.0                           180.0     6,306
# 829                          -145.0                           236.0    10,722
# 830                           -15.0                             7.0     3,647
# 834                           -40.0                           212.0     7,362
#
# [679 rows x 20 columns]

# %%
#check apartment data
for i in ['train_station','fitness_gym','hospital','shopping_center','park','natural_increase_2016_17']:
    sns.histplot(df[i],bins=50)
    plt.show()

# %%
###selecting data for house

# %%
for i in ['school','train_station','fitness_gym','hospital','shopping_center','park','natural_increase_2016_17']:
    sns.histplot(df1_h[i],bins=50)
    plt.show()

# %%
#delete outlier/ extreme points  for house

df = pd.read_csv("../data/curated/match_clean_house.csv")
df = df[df['school']<=50000]
df = df[df['train_station']<=100000]
df = df[df['fitness_gym']<=25000]
df = df[df['hospital']<=25000]
df = df[df['shopping_center']<=50000]
df = df[df['park']<=15000]
df = df[df['natural_increase_2016_17']>=10]

df.shape
# Out:
# (405, 20)

# %%
#save to csv

df.to_csv('../data/curated/match_house_16_s.csv')
df
# Out:
#      Unnamed: 0  Unnamed: 0.1  price            suburb  beds  baths  parking  \
# 5             5             5    720     ST KILDA EAST     3      2        1
# 6             6             6    850     ST KILDA EAST     3      1        0
# 7             7             7    780     ST KILDA EAST     3      1        0
# 8             8             8   1650     ST KILDA EAST     5      2        4
# 9             9             9    720     ST KILDA EAST     3      2        1
# ..          ...           ...    ...               ...   ...    ...      ...
# 481         481           481    500        SOMERVILLE     3      2        2
# 482         482           482    550      COBURG NORTH     3      1        2
# 483         483           483    350    SUNSHINE NORTH     3      1        1
# 485         485           485    450  BURNSIDE HEIGHTS     3      2        2
# 486         486           486    400          HILLSIDE     3      1        3
#
#      latitudes  longitudes  school  train_station  fitness_gym  hospital  \
# 5     -37.8692    144.9977  8801.2          740.6       1818.7     176.2
# 6     -37.8692    144.9977  8801.2          740.6       1818.7     176.2
# 7     -37.8692    144.9977  8801.2          740.6       1818.7     176.2
# 8     -37.8692    144.9977  8801.2          740.6       1818.7     176.2
# 9     -37.8692    144.9977  8801.2          740.6       1818.7     176.2
# ..         ...         ...     ...            ...          ...       ...
# 481   -38.2186    145.2182  9392.4         6435.0       4854.6   10188.3
# 482   -37.7500    144.9667  3099.5          888.5       1617.6    1255.4
# 483   -37.7750    144.8333  5655.2         1159.4       1384.3    3950.7
# 485   -37.7541    144.7651  3773.4         4544.8       5859.0    2764.3
# 486   -37.7034    144.7619  1338.7         2537.4       1967.6    5678.8
#
#      shopping_center    park  erp_2016  natural_increase_2016_17  \
# 5             1684.7  1184.2     17613                     195.0
# 6             1684.7  1184.2     17613                     195.0
# 7             1684.7  1184.2     17613                     195.0
# 8             1684.7  1184.2     17613                     195.0
# 9             1684.7  1184.2     17613                     195.0
# ..               ...     ...       ...                       ...
# 481          11544.9  3464.7     18878                      76.0
# 482           3204.2  1478.4      8112                      59.0
# 483           1418.2   474.8     12123                      75.0
# 485           1320.5  1817.3      6431                      93.0
# 486           2815.4  2055.4     21305                     318.0
#
#      net_internal_migration_2016_17  net_overseas_migration_2016_17 2016income
# 5                            -267.0                           375.0    11,686
# 6                            -267.0                           375.0    11,686
# 7                            -267.0                           375.0    11,686
# 8                            -267.0                           375.0    11,686
# 9                            -267.0                           375.0    11,686
# ..                              ...                             ...        ...
# 481                           113.0                            50.0    11,166
# 482                            99.0                           140.0     4,649
# 483                           -67.0                           200.0     5,690
# 485                           -52.0                            87.0     3,251
# 486                          1101.0                           189.0    11,999
#
# [405 rows x 20 columns]

# %%
#check house data
for i in ['train_station','fitness_gym','hospital','shopping_center','park','natural_increase_2016_17']:
    sns.histplot(df[i],bins=50)
    plt.show()

# %%
import os

os.remove('../data/curated/match_clean_apartment.csv')
os.remove('../data/curated/match_clean_house.csv')

# %%
for i in ['train_station','fitness_gym','hospital','shopping_center','park']:
    df = df[[i,'price']].groupby(i).mean().reset_index()
    sns.regplot(x=i,y='price',data=df1)
    plt.show()
