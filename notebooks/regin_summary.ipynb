# %%
import pandas as pd

# %%
box_hill_csv = pd.read_csv("../P2 dataset/kim/Box Hill.csv")
carlton_csv = pd.read_csv("../P2 dataset/kim/Carlton.csv")
colling_csv = pd.read_csv("../P2 dataset/kim/Collingwood.csv")
dock_csv = pd.read_csv("../P2 dataset/kim/Docklands.csv")
east_mel_csv = pd.read_csv("../P2 dataset/kim/East Melbourne.csv")
fle_csv = pd.read_csv("../P2 dataset/kim/Flemington.csv")
haw_csv = pd.read_csv("../P2 dataset/kim/Hawthorn.csv")
ken_csv = pd.read_csv("../P2 dataset/kim/Kensington.csv")
mel_csv = pd.read_csv("../P2 dataset/kim/Melbourne.csv")
north_mel_csv = pd.read_csv("../P2 dataset/kim/North Melbourne.csv")
park_csv = pd.read_csv("../P2 dataset/kim/Parkville.csv")
port_mel_csv = pd.read_csv("../P2 dataset/kim/Port Melbourne.csv")
rich_csv = pd.read_csv("../P2 dataset/kim/Richmond.csv")
south_mel_csv = pd.read_csv("../P2 dataset/kim/South Melbourne.csv")
south_yarra_csv = pd.read_csv("../P2 dataset/kim/South Yarra.csv .csv")
sbank_csv = pd.read_csv("../P2 dataset/kim/Southbank.csv")
stkida_csv = pd.read_csv("../P2 dataset/kim/St Kilda.csv")
west_mel_csv = pd.read_csv("../P2 dataset/kim/West Melbourne.csv")

# %%
box_hill = pd.DataFrame(box_hill_csv)
car = pd.DataFrame(carlton_csv)
colling = pd.DataFrame(colling_csv)
dock = pd.DataFrame(dock_csv)
eastmel = pd.DataFrame(east_mel_csv)
fle = pd.DataFrame(fle_csv)
haw = pd.DataFrame(haw_csv)
ken = pd.DataFrame(ken_csv)
mel = pd.DataFrame(mel_csv)
nmel = pd.DataFrame(north_mel_csv)
park = pd.DataFrame(park_csv)
portmel = pd.DataFrame(port_mel_csv)
rich = pd.DataFrame(rich_csv)
smel = pd.DataFrame(south_mel_csv)
syarra = pd.DataFrame(south_yarra_csv)
sbank = pd.DataFrame(sbank_csv)
stkilda = pd.DataFrame(stkida_csv)
wmel = pd.DataFrame(west_mel_csv)

# %%
box_hill.head()
box_hill.columns
box_hill.shape
# Out:
# (642, 9)

# %%
box_hill=box_hill[['Description','2018','2019','2020']]
car=car[['Description','2018','2019','2020']]
colling=colling[['Description','2018','2019','2020']]
dock=dock[['Description','2018','2019','2020']]
eastmel=eastmel[['Description','2018','2019','2020']]
fle=fle[['Description','2018','2019','2020']]
haw=haw[['Description','2018','2019','2020']]
ken=ken[['Description','2018','2019','2020']]
mel=mel[['Description','2018','2019','2020']]
nmel=nmel[['Description','2018','2019','2020']]
park=park[['Description','2018','2019','2020']]
portmel=portmel[['Description','2018','2019','2020']]
rich=rich[['Description','2018','2019','2020']]
smel=smel[['Description','2018','2019','2020']]
syarra=syarra[['Description','2018','2019','2020']]
sbank=sbank[['Description','2018','2019','2020']]
stkilda=stkilda[['Description','2018','2019','2020']]
wmel=wmel[['Description','2018','2019','2020']]

# %%
box_hill = box_hill.iloc[[0,1,2,3,8,211,212,215,219,220,252,255,256,266]]

# %%
box_hill = box_hill.rename(columns={'2020':'2020_BoxHill'})
box_hill.reset_index(drop=True, inplace=True)

# %%
car = car.rename(columns={'2020':'2020_Carlton'})
colling = colling.rename(columns={'2020':'2020_Collingwood'})
dock = dock.rename(columns={'2020':'2020_Dockland'})
eastmel = eastmel.rename(columns={'2020':'2020_E_Mel'})
fle = fle.rename(columns={'2020':'2020_Flemington'})
haw = haw.rename(columns={'2020':'2020_Hawthorn'})
ken = ken.rename(columns={'2020':'2020_Kensington'})
mel = mel.rename(columns={'2020':'2020_Mel'})
nmel = nmel.rename(columns={'2020':'2020_N_Mel'})
park = park.rename(columns={'2020':'2020_Parkville'})
portmel = portmel.rename(columns={'2020':'2020_Port_Mel'})
rich = rich.rename(columns={'2020':'2020_Richmond'})
smel = smel.rename(columns={'2020':'2020_S_Mel'})
syarra = syarra.rename(columns={'2020':'2020_S_Yarra'})
sbank = sbank.rename(columns={'2020':'2020_S_Bank'})
stkilda = stkilda.rename(columns={'2020':'2020_StKilda'})
wmel = wmel.rename(columns={'2020':'2020_W_Mel'})

# %%
box_hill.head
# Out:
# <bound method NDFrame.head of                                       Description       2018       2019  \
# 0             Estimated resident population (no.)    22627.0    23331.0
# 1                Population density (persons/km2)     3226.9     3327.3
# 2     Estimated resident population - males (no.)    11108.0    11577.0
# 3   Estimated resident population - females (no.)    11519.0    11754.0
# 4   Working age population (aged 15-64 years) (%)       73.7       74.5
# 5           Accommodation and food services (no.)      184.0      196.0
# 6         Transport, postal and warehousing (no.)      136.0      162.0
# 7   Rental, hiring and real estate services (no.)      403.0      447.0
# 8                    Education and training (no.)       52.0       58.0
# 9         Health care and social assistance (no.)      218.0      232.0
# 10             Value of residential building ($m)      118.0      150.0
# 11             Houses - number of transfers (no.)      157.0      122.0
# ...

# %%
result = pd.merge(box_hill, car,how='left', on=['Description'])
result = pd.merge(result, colling,how='left', on=['Description'])
result = pd.merge(result, dock,how='left', on=['Description'])
result = pd.merge(result, eastmel,how='left', on=['Description'])
result = pd.merge(result, fle,how='left', on=['Description'])
result = pd.merge(result, haw,how='left', on=['Description'])
result = pd.merge(result, ken,how='left', on=['Description'])
result = pd.merge(result, mel,how='left', on=['Description'])
result = pd.merge(result, nmel,how='left', on=['Description'])
result = pd.merge(result, park,how='left', on=['Description'])
result = pd.merge(result, portmel,how='left', on=['Description'])
result = pd.merge(result, rich,how='left', on=['Description'])
result = pd.merge(result, smel,how='left', on=['Description'])
result = pd.merge(result, syarra,how='left', on=['Description'])
result = pd.merge(result, sbank,how='left', on=['Description'])
result = pd.merge(result, stkilda,how='left', on=['Description'])
result = pd.merge(result, wmel,how='left', on=['Description'])
# Out:
# /var/folders/mz/ytcv9vg56yqf64xqlxptmkbc0000gn/T/ipykernel_13661/3737355814.py:3: FutureWarning: Passing 'suffixes' which cause duplicate columns {'2019_x', '2018_x'} in the result is deprecated and will raise a MergeError in a future version.
#   result = pd.merge(result, dock,how='left', on=['Description'])
# /var/folders/mz/ytcv9vg56yqf64xqlxptmkbc0000gn/T/ipykernel_13661/3737355814.py:5: FutureWarning: Passing 'suffixes' which cause duplicate columns {'2019_x', '2018_x'} in the result is deprecated and will raise a MergeError in a future version.
#   result = pd.merge(result, fle,how='left', on=['Description'])
# /var/folders/mz/ytcv9vg56yqf64xqlxptmkbc0000gn/T/ipykernel_13661/3737355814.py:7: FutureWarning: Passing 'suffixes' which cause duplicate columns {'2019_x', '2018_x'} in the result is deprecated and will raise a MergeError in a future version.
#   result = pd.merge(result, ken,how='left', on=['Description'])
# ...

# %%
result.head(14)
# Out:
#                                       Description     2018_x     2019_x  \
# 0             Estimated resident population (no.)    22627.0    23331.0
# 1                Population density (persons/km2)     3226.9     3327.3
# 2     Estimated resident population - males (no.)    11108.0    11577.0
# 3   Estimated resident population - females (no.)    11519.0    11754.0
# 4   Working age population (aged 15-64 years) (%)       73.7       74.5
# 5           Accommodation and food services (no.)      184.0      196.0
# 6         Transport, postal and warehousing (no.)      136.0      162.0
# 7   Rental, hiring and real estate services (no.)      403.0      447.0
# 8                    Education and training (no.)       52.0       58.0
# 9         Health care and social assistance (no.)      218.0      232.0
# 10             Value of residential building ($m)      118.0      150.0
# 11             Houses - number of transfers (no.)      157.0      122.0
# ...

# %%
result.to_csv("../P2 dataset/clean dataset/region_summary.csv")
