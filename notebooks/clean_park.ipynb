# %%
import pandas as pd

# %%
df = pd.read_csv("../data/curated/park_reserve.csv")
#remove data which does not have latitude or longitude
df = df.dropna(subset=['Longitude','Latitude'])
df
# Out:
#       Unnamed: 0  Facility ID                    Facility Name  \
# 0              0   ALPINE5519  Pioneer Park Recreation Reserve
# 1              1  ALPINE10928  Mount Beauty recreation Reserve
# 2              2  ALPINE10924      Dederang Recreation reserve
# 3              3  ALPINE10932              RC McNamara Reserve
# 4              4  ALPINE10942    Porepunkah Recreation Reserve
# ...          ...          ...                              ...
# 1906        1906  YARRIA12731         Tempy Recreation Reserve
# 1907        1907  YARRIA12739     Woomelang Recreation Reserve
# 1908        1908  YARRIA12742       Yaapeet Recreation Reserve
# 1909        1909  YARRIA12743         Warracknabeal Skate Park
# 1910        1910  YARRIA12721            Murtoa Tennis Reserve
#
#           Street Name    Suburb/Town   Pcode   Latitude   Longitude  \
# 0          Coronation         BRIGHT  3741.0 -36.737199  146.973353
# 1           Lakeside    MOUNT BEAUTY  3699.0 -36.739256  147.172162
# ...

# %%
#set the type of the dataframe
df = df.astype(str)

# %%
#remove rows with name contain 'reserve' or 'Resever'
df_park = df[~df['Facility Name'].str.contains('eserve')]

# %%
df = df_park.dropna()
df.duplicated(subset=['Facility Name','Latitude','Longitude'])
df.reset_index(drop=True, inplace=True)

# %%
new = df.drop_duplicates(subset=['Facility Name','Latitude','Longitude'], keep='first')

# %%
only_park = new[new['Facility Name'].str.contains('park', case=False)]
only_park
# Out:
#     Unnamed: 0  Facility ID                   Facility Name  Street Name  \
# 0            5  ALPINE10944         Alpine Park Wandiligong  White Star
# 1            8  ALPINE10935                   Memorial Park        Duke
# 2            9   ALPINE5428               Big Hill MTB Park          nan
# 3           11  ALPINE10916  Bright Skate Park (lions Park)       Delany
# 4           12  ALPINE10940                      Cundy Park    Standish
# ..         ...          ...                             ...          ...
# 481       1886  YARRAR11429              Fit Chirnside park    Maroondah
# 482       1887  YARRAR11428     Chirnside Park Country Club    Kingswood
# 483       1895  YARRAR11471                     Esther Park       esther
# 484       1897  YARRIA12734                      Anzac Park        Scott
# 485       1909  YARRIA12743        Warracknabeal Skate Park         Lyle
#
#         Suburb/Town   Pcode             Latitude           Longitude  \
# ...

# %%
only_park.reset_index(drop=True, inplace=True)

# %%
only_park.to_csv("../data/curated/clean_park.csv")

only_park
# Out:
#     Unnamed: 0  Facility ID                   Facility Name  Street Name  \
# 0            5  ALPINE10944         Alpine Park Wandiligong  White Star
# 1            8  ALPINE10935                   Memorial Park        Duke
# 2            9   ALPINE5428               Big Hill MTB Park          nan
# 3           11  ALPINE10916  Bright Skate Park (lions Park)       Delany
# 4           12  ALPINE10940                      Cundy Park    Standish
# ..         ...          ...                             ...          ...
# 480       1886  YARRAR11429              Fit Chirnside park    Maroondah
# 481       1887  YARRAR11428     Chirnside Park Country Club    Kingswood
# 482       1895  YARRAR11471                     Esther Park       esther
# 483       1897  YARRIA12734                      Anzac Park        Scott
# 484       1909  YARRIA12743        Warracknabeal Skate Park         Lyle
#
#         Suburb/Town   Pcode             Latitude           Longitude  \
# ...
